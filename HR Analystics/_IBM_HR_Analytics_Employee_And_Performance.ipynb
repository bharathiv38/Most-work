# %%
#lets import dependencies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#loading dataset to pandas dataframe
df = pd.read_csv(r"C:\Users\User\Downloads\WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
#print first 5 rows of dataset
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# std        602.024335                 1.093082    20.329428        0.711561
# min          1.000000                 1.000000    30.000000        1.000000
# 25%        491.250000                 2.000000    48.000000        2.000000
# 50%       1020.500000                 3.000000    66.000000        3.000000
# 75%       1555.750000                 4.000000    83.750000        3.000000
# max       2068.000000                 4.000000   100.000000        4.000000
#
#           JobLevel  ...  RelationshipSatisfaction  StandardHours  \
# count  1470.000000  ...               1470.000000         1470.0
# mean      2.063946  ...                  2.712245           80.0
# std       1.106940  ...                  1.081209            0.0
# min       1.000000  ...                  1.000000           80.0
# 25%       1.000000  ...                  2.000000           80.0
# 50%       2.000000  ...                  3.000000           80.0
# 75%       3.000000  ...                  4.000000           80.0
# max       5.000000  ...                  4.000000           80.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       1470.000000        1470.000000            1470.000000
# mean           0.793878          11.279592               2.799320
# std            0.852077           7.780782               1.289271
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000          10.000000               3.000000
# 75%            1.000000          15.000000               3.000000
# max            3.000000          40.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1470.000000     1470.000000         1470.000000
# mean          2.761224        7.008163            4.229252
# std           0.706476        6.126525            3.623137
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       40.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              1470.000000           1470.000000
# mean                  2.187755              4.123129
# std                   3.222430              3.568136
# min                   0.000000              0.000000
# 25%                   0.000000              2.000000
# 50%                   1.000000              3.000000
# 75%                   3.000000              7.000000
# max                  15.000000             17.000000
#
# [8 rows x 26 columns]

# %%
#finding nul values
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
for column in df.columns:
    print(f"{column}:Number of unique values {df[column].nunique()}")
    print("========================================================")
# Out:
# Age:Number of unique values 43
# ========================================================
# Attrition:Number of unique values 2
# ========================================================
# BusinessTravel:Number of unique values 3
# ========================================================
# DailyRate:Number of unique values 886
# ========================================================
# Department:Number of unique values 3
# ========================================================
# DistanceFromHome:Number of unique values 29
# ========================================================
# Education:Number of unique values 5
# ========================================================
# EducationField:Number of unique values 6
# ========================================================
# EmployeeCount:Number of unique values 1
# ========================================================
# EmployeeNumber:Number of unique values 1470
# ========================================================
# EnvironmentSatisfaction:Number of unique values 4
# ========================================================
# Gender:Number of unique values 2
# ========================================================
# HourlyRate:Number of unique values 71
# ========================================================
# JobInvolvement:Number of unique values 4
# ========================================================
# JobLevel:Number of unique values 5
# ========================================================
# JobRole:Number of unique values 9
# ========================================================
# JobSatisfaction:Number of unique values 4
# ========================================================
# MaritalStatus:Number of unique values 3
# ========================================================
# MonthlyIncome:Number of unique values 1349
# ========================================================
# MonthlyRate:Number of unique values 1427
# ========================================================
# NumCompaniesWorked:Number of unique values 10
# ========================================================
# Over18:Number of unique values 1
# ========================================================
# OverTime:Number of unique values 2
# ========================================================
# PercentSalaryHike:Number of unique values 15
# ========================================================
# PerformanceRating:Number of unique values 2
# ========================================================
# RelationshipSatisfaction:Number of unique values 4
# ========================================================
# StandardHours:Number of unique values 1
# ========================================================
# StockOptionLevel:Number of unique values 4
# ========================================================
# TotalWorkingYears:Number of unique values 40
# ========================================================
# TrainingTimesLastYear:Number of unique values 7
# ========================================================
# WorkLifeBalance:Number of unique values 4
# ========================================================
# YearsAtCompany:Number of unique values 37
# ========================================================
# YearsInCurrentRole:Number of unique values 19
# ========================================================
# YearsSinceLastPromotion:Number of unique values 16
# ========================================================
# YearsWithCurrManager:Number of unique values 18
# ========================================================

# %% [markdown]
# We notice that 'EmployeeCount', 'Over18', 'StandardHours' have only one unique values and 'EmployeeNumber' has 1470 unique values. This features aren't useful for us, So we are going to drop those columns.

# %%
df.drop(['EmployeeCount','Over18','StandardHours'],axis=1,inplace=True)

# %% [markdown]
# # Categorical Features

# %%
object_col = []
for column in df.columns:
    if df[column].dtypes == object and len(df[column].unique()) <= 30:
        object_col.append(column)
        print(f"{column} : {df[column].unique()}")
        print(df[column].value_counts())
        print("==================================================")
object_col.remove('Attrition')
# Out:
# Attrition : ['Yes' 'No']
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
# ==================================================
# BusinessTravel : ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# ==================================================
# Department : ['Sales' 'Research & Development' 'Human Resources']
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# ==================================================
# EducationField : ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
# ==================================================
# Gender : ['Female' 'Male']
# Male      882
# Female    588
# Name: Gender, dtype: int64
# ==================================================
# JobRole : ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64
# ==================================================
# MaritalStatus : ['Single' 'Married' 'Divorced']
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64
# ==================================================
# OverTime : ['Yes' 'No']
# No     1054
# Yes     416
# Name: OverTime, dtype: int64
# ==================================================

# %%
len(object_col)
# Out:
# 7

# %%
from sklearn.preprocessing import LabelEncoder

label = LabelEncoder()
df['Attrition'] = label.fit_transform(df.Attrition)

# %% [markdown]
# # Numerical Features

# %%
disc_col =[]
for column in df.columns:
    if df[column].dtypes != object and df[column].nunique() < 30:
        print(f"{column}:{df[column].unique()}")
        disc_col.append(column)
        print("==================================================")
disc_col.remove("Attrition")
# Out:
# Attrition:[1 0]
# ==================================================
# DistanceFromHome:[ 1  8  2  3 24 23 27 16 15 26 19 21  5 11  9  7  6 10  4 25 12 18 29 22
#  14 20 28 17 13]
# ==================================================
# Education:[2 1 4 3 5]
# ==================================================
# EnvironmentSatisfaction:[2 3 4 1]
# ==================================================
# JobInvolvement:[3 2 4 1]
# ==================================================
# JobLevel:[2 1 3 4 5]
# ==================================================
# JobSatisfaction:[4 2 3 1]
# ==================================================
# NumCompaniesWorked:[8 1 6 9 0 4 5 2 7 3]
# ==================================================
# PercentSalaryHike:[11 23 15 12 13 20 22 21 17 14 16 18 19 24 25]
# ==================================================
# PerformanceRating:[3 4]
# ==================================================
# RelationshipSatisfaction:[1 4 2 3]
# ==================================================
# StockOptionLevel:[0 1 3 2]
# ==================================================
# TrainingTimesLastYear:[0 3 2 5 1 4 6]
# ==================================================
# WorkLifeBalance:[1 3 2 4]
# ==================================================
# YearsInCurrentRole:[ 4  7  0  2  5  9  8  3  6 13  1 15 14 16 11 10 12 18 17]
# ==================================================
# YearsSinceLastPromotion:[ 0  1  3  2  7  4  8  6  5 15  9 13 12 10 11 14]
# ==================================================
# YearsWithCurrManager:[ 5  7  0  2  6  8  3 11 17  1  4 12  9 10 15 13 16 14]
# ==================================================

# %%
cont_col = []
for column in df.columns:
    if df[column].dtypes != object and df[column].nunique() > 30:
        print(f"{column}: Minimum: {df[column].min()},Maximum:{df[column].max()}")
        cont_col.append(column)
        print("======================================")
# Out:
# Age: Minimum: 18,Maximum:60
# ======================================
# DailyRate: Minimum: 102,Maximum:1499
# ======================================
# EmployeeNumber: Minimum: 1,Maximum:2068
# ======================================
# HourlyRate: Minimum: 30,Maximum:100
# ======================================
# MonthlyIncome: Minimum: 1009,Maximum:19999
# ======================================
# MonthlyRate: Minimum: 2094,Maximum:26999
# ======================================
# TotalWorkingYears: Minimum: 0,Maximum:40
# ======================================
# YearsAtCompany: Minimum: 0,Maximum:40
# ======================================

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(20,20))

for i,column in enumerate(disc_col,1):
    plt.subplot(4,4,i)
    df[df['Attrition'] == 0][column].hist(bins=35,color='blue',label='Attrition=NO',alpha=0.6)
    df[df['Attrition'] == 1][column].hist(bins=35,color='red',label='Attrition=YES',alpha=0.6)
    plt.legend()
    plt.xlabel(column)

# %% [markdown]
# It seems that EnvironmentSatisfaction, JobSatisfaction, PerformanceRating, and RelationshipSatisfaction features don't have big impact on the detrmination of Attrition of employees.

# %%
plt.figure(figsize=(20,10))

for i, column in enumerate(cont_col,1):
    plt.subplot(2,4,i)
    df[df['Attrition'] == 0][column].hist(bins=35,color='blue',label='Attrition =NO',alpha=0.6)
    df[df['Attrition'] == 1][column].hist(bins=35,color='red',label='Attrition = YES',alpha=0.6)
    plt.legend()
    plt.xlabel(column)

# %%
plt.figure(figsize=(15,20))

for i, column in enumerate(object_col,1):
    plt.subplot(3,3,i)
    df[df['Attrition'] == 0][column].hist(bins=35,color='blue',label ='Attrition == NO',alpha=0.6)
    df[df['Attrition'] == 1][column].hist(bins=35,color='red',label='Attrition =YES',alpha=0.6)
    plt.legend()
    plt.xlabel(column)
    plt.xticks(rotation=45)

# %% [markdown]
# The workers with low JobLevel, MonthlyIncome, YearAtCompany, and TotalWorkingYears are more likely to quit there jobs.
# BusinessTravel : The workers who travel alot are more likely to quit then other employees.
#
# Department : The worker in Research & Development are more likely to stay then the workers on other departement.
#
# EducationField : The workers with Human Resources and Technical Degree are more likely to quit then employees from other fields of educations.
#
# Gender : The Male are more likely to quit.
#
# JobRole : The workers in Laboratory Technician, Sales Representative, and Human Resources are more likely to quit the workers in other positions.
#
# MaritalStatus : The workers who have Single marital status are more likely to quit the Married, and Divorced.
#
# OverTime : The workers who work more hours are likely to quit then others.

# %% [markdown]
# # Correlation Matrix

# %%
plt.figure(figsize=(30,30))
sns.heatmap(df.corr(),annot=True,cmap='RdYlGn',annot_kws={"size":15})
# Out:
# <AxesSubplot:>

# %%
col = df.corr().nlargest(20,'Attrition').Attrition.index
plt.figure(figsize=(15,15))
sns.heatmap(df[col].corr(),annot=True,cmap='RdYlGn',annot_kws={"size":10})
# Out:
# <AxesSubplot:>

# %%
df.drop('Attrition',axis=1).corrwith(df.Attrition).plot(kind='barh',figsize=(10,7))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Analysis of correlation results (sample analysis):
#
# Monthly income is highly correlated with Job level.
#
# Job level is highly correlated with total working hours.
#
# Monthly income is highly correlated with total working hours.
#
# Age is also positively correlated with the Total working hours.
#
# Marital status and stock option level are negatively correlated

# %% [markdown]
# # Data Processing

# %%
#Transform categorical into dummies
dummy_col = [column for column in df.drop("Attrition",axis=1).columns if df[column].nunique() < 20]
data = pd.get_dummies(df,columns=dummy_col,drop_first=True,dtype='uint8')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Columns: 137 entries, Age to YearsWithCurrManager_17
# dtypes: int32(1), int64(9), uint8(127)
# memory usage: 291.5 KB

# %%
print(data.shape)

#remove duplicate features
data = data.T.drop_duplicates()
data = data.T

#remove duplicaterow
data.drop_duplicates(inplace=True)

print(data.shape)
# Out:
# (1470, 137)
# (1470, 137)

# %%
data.shape
# Out:
# (1470, 137)

# %%
data.drop('Attrition',axis=1).corrwith(data.Attrition).sort_values().plot(kind='barh',figsize=(10,30))
# Out:
# <AxesSubplot:>

# %%
feature_correlation = data.drop('Attrition',axis=1).corrwith(data.Attrition).sort_values()
model_col = feature_correlation[np.abs(feature_correlation) > 0.02].index
len(model_col)
# Out:
# 92

# %% [markdown]
# # Applying machine learning algorithms

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X = data.drop('Attrition', axis=1)
y = data.Attrition

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42,
                                                    stratify=y)

scaler = StandardScaler()
X_train_std = scaler.fit_transform(X_train)
X_test_std = scaler.transform(X_test)
X_std = scaler.transform(X)

# %%
def feature_imp(df, model):
    fi = pd.DataFrame()
    fi["feature"] = df.columns
    fi["importance"] = model.feature_importances_
    return fi.sort_values(by="importance", ascending=False)

# %% [markdown]
# # What defines success?
# We have an imbalanced data, so if we predict that all our employees will stay we'll have an accuracy of 83.90%.

# %%
y_test.value_counts()[0] / y_test.shape[0]
# Out:
# 0.8390022675736961

# %%
stay = (y_train.value_counts()[0] / y_train.shape)[0]
leave = (y_train.value_counts()[1] / y_train.shape)[0]

print("===============TRAIN=================")
print(f"Staying Rate: {stay * 100:.2f}%")
print(f"Leaving Rate: {leave * 100 :.2f}%")

stay = (y_test.value_counts()[0] / y_test.shape)[0]
leave = (y_test.value_counts()[1] / y_test.shape)[0]

print("===============TEST=================")
print(f"Staying Rate: {stay * 100:.2f}%")
print(f"Leaving Rate: {leave * 100 :.2f}%")
# Out:
# ===============TRAIN=================
# Staying Rate: 83.87%
# Leaving Rate: 16.13%
# ===============TEST=================
# Staying Rate: 83.90%
# Leaving Rate: 16.10%

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score

def print_score(clf, X_train, y_train, X_test, y_test, train=True):
    if train:
        pred = clf.predict(X_train)
        print("Train Result:\n================================================")
        print(f"Accuracy Score: {accuracy_score(y_train, pred) * 100:.2f}%")
        print("_______________________________________________")
        print("Classification Report:", end='')
        print(f"\tPrecision Score: {precision_score(y_train, pred) * 100:.2f}%")
        print(f"\t\t\tRecall Score: {recall_score(y_train, pred) * 100:.2f}%")
        print(f"\t\t\tF1 score: {f1_score(y_train, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(y_train, pred)}\n")
        
    elif train==False:
        pred = clf.predict(X_test)
        print("Test Result:\n================================================")        
        print(f"Accuracy Score: {accuracy_score(y_test, pred) * 100:.2f}%")
        print("_______________________________________________")
        print("Classification Report:", end='')
        print(f"\tPrecision Score: {precision_score(y_test, pred) * 100:.2f}%")
        print(f"\t\t\tRecall Score: {recall_score(y_test, pred) * 100:.2f}%")
        print(f"\t\t\tF1 score: {f1_score(y_test, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(y_test, pred)}\n")

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr_classifier = LogisticRegression(solver='liblinear', penalty='l1')
lr_classifier.fit(X_train_std, y_train)

print_score(lr_classifier, X_train_std, y_train, X_test_std, y_test, train=True)
print_score(lr_classifier, X_train_std, y_train, X_test_std, y_test, train=False)
# Out:
# Train Result:
# ================================================
# Accuracy Score: 92.81%
# _______________________________________________
# Classification Report:	Precision Score: 87.70%
# 			Recall Score: 64.46%
# 			F1 score: 74.31%
# _______________________________________________
# Confusion Matrix:
#  [[848  15]
#  [ 59 107]]
#
# Test Result:
# ================================================
# Accuracy Score: 85.94%
# _______________________________________________
# Classification Report:	Precision Score: 59.57%
# 			Recall Score: 39.44%
# 			F1 score: 47.46%
# _______________________________________________
# Confusion Matrix:
#  [[351  19]
#  [ 43  28]]

# %%
from sklearn.metrics import plot_confusion_matrix, plot_roc_curve

disp = plot_confusion_matrix(lr_classifier, X_test_std, y_test, 
                             cmap='Blues', values_format='d', 
                             display_labels=['Stay', 'Churn'])

# %%
disp = plot_roc_curve(lr_classifier, X_test_std, y_test)

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rand_forest = RandomForestClassifier(n_estimators=1200, 
#                                      bootstrap=False,
#                                      class_weight={0:stay, 1:leave}
                                    )
rand_forest.fit(X_train, y_train)

print_score(rand_forest, X_train, y_train, X_test, y_test, train=True)
print_score(rand_forest, X_train, y_train, X_test, y_test, train=False)
# Out:
# Train Result:
# ================================================
# Accuracy Score: 100.00%
# _______________________________________________
# Classification Report:	Precision Score: 100.00%
# 			Recall Score: 100.00%
# 			F1 score: 100.00%
# _______________________________________________
# Confusion Matrix:
#  [[863   0]
#  [  0 166]]
#
# Test Result:
# ================================================
# Accuracy Score: 83.90%
# _______________________________________________
# Classification Report:	Precision Score: 50.00%
# 			Recall Score: 8.45%
# 			F1 score: 14.46%
# _______________________________________________
# Confusion Matrix:
#  [[364   6]
#  [ 65   6]]

# %%
disp = plot_roc_curve(lr_classifier, X_test_std, y_test)
plot_roc_curve(rand_forest, X_test, y_test, ax=disp.ax_)

# %%
df = feature_imp(X, rand_forest)[:40]
df.set_index('feature', inplace=True)
df.plot(kind='barh', figsize=(10, 10))
plt.title('Feature Importance according to Random Forest')
# Out:
# Text(0.5, 1.0, 'Feature Importance according to Random Forest')

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVC

svc = SVC(kernel='linear')
svc.fit(X_train_std, y_train)

print_score(svc, X_train_std, y_train, X_test_std, y_test, train=True)
print_score(svc, X_train_std, y_train, X_test_std, y_test, train=False)
# Out:
# Train Result:
# ================================================
# Accuracy Score: 94.75%
# _______________________________________________
# Classification Report:	Precision Score: 95.16%
# 			Recall Score: 71.08%
# 			F1 score: 81.38%
# _______________________________________________
# Confusion Matrix:
#  [[857   6]
#  [ 48 118]]
#
# Test Result:
# ================================================
# Accuracy Score: 83.90%
# _______________________________________________
# Classification Report:	Precision Score: 50.00%
# 			Recall Score: 35.21%
# 			F1 score: 41.32%
# _______________________________________________
# Confusion Matrix:
#  [[345  25]
#  [ 46  25]]

# %%
disp = plot_roc_curve(lr_classifier, X_test_std, y_test)
plot_roc_curve(rand_forest, X_test, y_test, ax=disp.ax_)
plot_roc_curve(svc, X_test_std, y_test, ax=disp.ax_)

# %%
df = feature_imp(X, rand_forest)[:40]
df.set_index('feature', inplace=True)
df.plot(kind='barh', figsize=(10, 10))
plt.title('Feature Importance according to Random Forest')
# Out:
# Text(0.5, 1.0, 'Feature Importance according to Random Forest')

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVC

svc = SVC(kernel='linear')
svc.fit(X_train_std, y_train)

print_score(svc, X_train_std, y_train, X_test_std, y_test, train=True)
print_score(svc, X_train_std, y_train, X_test_std, y_test, train=False)
# Out:
# Train Result:
# ================================================
# Accuracy Score: 94.75%
# _______________________________________________
# Classification Report:	Precision Score: 95.16%
# 			Recall Score: 71.08%
# 			F1 score: 81.38%
# _______________________________________________
# Confusion Matrix:
#  [[857   6]
#  [ 48 118]]
#
# Test Result:
# ================================================
# Accuracy Score: 83.90%
# _______________________________________________
# Classification Report:	Precision Score: 50.00%
# 			Recall Score: 35.21%
# 			F1 score: 41.32%
# _______________________________________________
# Confusion Matrix:
#  [[345  25]
#  [ 46  25]]

# %%
disp = plot_roc_curve(lr_classifier, X_test_std, y_test)
plot_roc_curve(rand_forest, X_test, y_test, ax=disp.ax_)
plot_roc_curve(svc, X_test_std, y_test, ax=disp.ax_)

# %% [markdown]
# # XGBoost Classifier

# %%
from xgboost import XGBClassifier

xgb_clf = XGBClassifier()
xgb_clf.fit(X_train, y_train)

print_score(xgb_clf, X_train, y_train, X_test, y_test, train=True)
print_score(xgb_clf, X_train, y_train, X_test, y_test, train=False)
# Out:
# Train Result:
# ================================================
# Accuracy Score: 100.00%
# _______________________________________________
# Classification Report:	Precision Score: 100.00%
# 			Recall Score: 100.00%
# 			F1 score: 100.00%
# _______________________________________________
# Confusion Matrix:
#  [[863   0]
#  [  0 166]]
#
# Test Result:
# ================================================
# Accuracy Score: 85.03%
# _______________________________________________
# Classification Report:	Precision Score: 57.14%
# 			Recall Score: 28.17%
# 			F1 score: 37.74%
# _______________________________________________
# Confusion Matrix:
#  [[355  15]
#  [ 51  20]]

# %%
disp = plot_roc_curve(lr_classifier, X_test_std, y_test)
plot_roc_curve(rand_forest, X_test, y_test, ax=disp.ax_)
plot_roc_curve(svc, X_test_std, y_test, ax=disp.ax_)
plot_roc_curve(xgb_clf, X_test, y_test, ax=disp.ax_)

# %%
df = feature_imp(X, xgb_clf)[:35]
df.set_index('feature', inplace=True)
df.plot(kind='barh', figsize=(10, 8))
plt.title('Feature Importance according to XGBoost')
# Out:
# Text(0.5, 1.0, 'Feature Importance according to XGBoost')

# %% [markdown]
# # Artificial Neural Networks (ANNs)

# %%
X_train_std = np.array(X_train_std)
X_test_std = np.array(X_test_std)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
def print_score_ann(label, prediction, train=True):
    if train:
        print("Train Result:\n================================================")
        print(f"Accuracy Score: {accuracy_score(label, prediction) * 100:.2f}%")
        print("_______________________________________________")
        print("Classification Report:", end='')
        print(f"\tPrecision Score: {precision_score(label, prediction) * 100:.2f}%")
        print(f"\t\t\tRecall Score: {recall_score(label, prediction) * 100:.2f}%")
        print(f"\t\t\tF1 score: {f1_score(label, prediction) * 100:.2f}%")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(y_train, prediction)}\n")
        
    elif train==False:
        print("Test Result:\n================================================")        
        print(f"Accuracy Score: {accuracy_score(label, prediction) * 100:.2f}%")
        print("_______________________________________________")
        print("Classification Report:", end='')
        print(f"\tPrecision Score: {precision_score(label, prediction) * 100:.2f}%")
        print(f"\t\t\tRecall Score: {recall_score(label, prediction) * 100:.2f}%")
        print(f"\t\t\tF1 score: {f1_score(label, prediction) * 100:.2f}%")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(label, prediction)}\n")

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

model = Sequential()

model.add(Dense(X_train.shape[1], activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(32, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.4))

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', 
              loss='binary_crossentropy', 
              metrics=['accuracy'])

r = model.fit(X_train_std, y_train, 
              validation_data=(X_test_std, y_test), 
              epochs=50, 
              class_weight={0:1, 1:2}
             )
# Out:
# Epoch 1/50
# 33/33 [==============================] - 4s 32ms/step - loss: 0.7155 - accuracy: 0.8251 - val_loss: 0.5594 - val_accuracy: 0.8390
# Epoch 2/50
# 33/33 [==============================] - 0s 13ms/step - loss: 0.6670 - accuracy: 0.8358 - val_loss: 0.5097 - val_accuracy: 0.8390
# Epoch 3/50
# 33/33 [==============================] - 1s 15ms/step - loss: 0.6339 - accuracy: 0.8377 - val_loss: 0.4519 - val_accuracy: 0.8390
# Epoch 4/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.5792 - accuracy: 0.8435 - val_loss: 0.4508 - val_accuracy: 0.8503
# Epoch 5/50
# 33/33 [==============================] - 0s 15ms/step - loss: 0.5406 - accuracy: 0.8542 - val_loss: 0.4095 - val_accuracy: 0.8277
# Epoch 6/50
# 33/33 [==============================] - 0s 15ms/step - loss: 0.4794 - accuracy: 0.8620 - val_loss: 0.4016 - val_accuracy: 0.8345
# Epoch 7/50
# 33/33 [==============================] - 0s 14ms/step - loss: 0.4414 - accuracy: 0.8678 - val_loss: 0.4353 - val_accuracy: 0.8254
# Epoch 8/50
# 33/33 [==============================] - 0s 14ms/step - loss: 0.4060 - accuracy: 0.8882 - val_loss: 0.4683 - val_accuracy: 0.7823
# Epoch 9/50
# 33/33 [==============================] - 1s 16ms/step - loss: 0.3367 - accuracy: 0.9028 - val_loss: 0.4802 - val_accuracy: 0.8299
# Epoch 10/50
# 33/33 [==============================] - 1s 15ms/step - loss: 0.2520 - accuracy: 0.9252 - val_loss: 0.5410 - val_accuracy: 0.8322
# Epoch 11/50
# 33/33 [==============================] - 0s 14ms/step - loss: 0.2686 - accuracy: 0.9203 - val_loss: 0.5638 - val_accuracy: 0.7982
# Epoch 12/50
# 33/33 [==============================] - 0s 14ms/step - loss: 0.2490 - accuracy: 0.9164 - val_loss: 0.5663 - val_accuracy: 0.8322
# Epoch 13/50
# 33/33 [==============================] - 1s 16ms/step - loss: 0.2374 - accuracy: 0.9368 - val_loss: 0.5459 - val_accuracy: 0.8435
# Epoch 14/50
# 33/33 [==============================] - 0s 15ms/step - loss: 0.1803 - accuracy: 0.9378 - val_loss: 0.5708 - val_accuracy: 0.8435
# Epoch 15/50
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1627 - accuracy: 0.9504 - val_loss: 0.6755 - val_accuracy: 0.8231
# Epoch 16/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.1318 - accuracy: 0.9582 - val_loss: 0.7003 - val_accuracy: 0.8277
# Epoch 17/50
# 33/33 [==============================] - 0s 14ms/step - loss: 0.1229 - accuracy: 0.9602 - val_loss: 0.7233 - val_accuracy: 0.8390
# Epoch 18/50
# 33/33 [==============================] - 0s 14ms/step - loss: 0.1033 - accuracy: 0.9708 - val_loss: 0.8495 - val_accuracy: 0.8367
# Epoch 19/50
# 33/33 [==============================] - 0s 14ms/step - loss: 0.1025 - accuracy: 0.9747 - val_loss: 0.8866 - val_accuracy: 0.8413
# Epoch 20/50
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0639 - accuracy: 0.9864 - val_loss: 1.0357 - val_accuracy: 0.8367
# Epoch 21/50
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0833 - accuracy: 0.9718 - val_loss: 0.9653 - val_accuracy: 0.8413
# Epoch 22/50
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0988 - accuracy: 0.9747 - val_loss: 0.9564 - val_accuracy: 0.8367
# Epoch 23/50
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0522 - accuracy: 0.9854 - val_loss: 1.0747 - val_accuracy: 0.8435
# Epoch 24/50
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0551 - accuracy: 0.9864 - val_loss: 1.1537 - val_accuracy: 0.8413
# Epoch 25/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0745 - accuracy: 0.9845 - val_loss: 1.1696 - val_accuracy: 0.8345
# Epoch 26/50
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0727 - accuracy: 0.9835 - val_loss: 1.1221 - val_accuracy: 0.8345
# Epoch 27/50
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0668 - accuracy: 0.9815 - val_loss: 1.1872 - val_accuracy: 0.8390
# Epoch 28/50
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0620 - accuracy: 0.9854 - val_loss: 1.1956 - val_accuracy: 0.8481
# Epoch 29/50
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0500 - accuracy: 0.9854 - val_loss: 1.0739 - val_accuracy: 0.8299
# Epoch 30/50
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0344 - accuracy: 0.9893 - val_loss: 1.2565 - val_accuracy: 0.8390
# Epoch 31/50
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0353 - accuracy: 0.9913 - val_loss: 1.2952 - val_accuracy: 0.8367
# Epoch 32/50
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0530 - accuracy: 0.9835 - val_loss: 1.3259 - val_accuracy: 0.8549
# Epoch 33/50
# 33/33 [==============================] - 0s 15ms/step - loss: 0.0531 - accuracy: 0.9913 - val_loss: 1.2271 - val_accuracy: 0.8481
# Epoch 34/50
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0327 - accuracy: 0.9903 - val_loss: 1.2540 - val_accuracy: 0.8413
# Epoch 35/50
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0318 - accuracy: 0.9932 - val_loss: 1.2888 - val_accuracy: 0.8413
# Epoch 36/50
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0376 - accuracy: 0.9883 - val_loss: 1.4943 - val_accuracy: 0.8458
# Epoch 37/50
# 33/33 [==============================] - 0s 15ms/step - loss: 0.0282 - accuracy: 0.9932 - val_loss: 1.4857 - val_accuracy: 0.8413
# Epoch 38/50
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0319 - accuracy: 0.9913 - val_loss: 1.5292 - val_accuracy: 0.8390
# Epoch 39/50
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0346 - accuracy: 0.9913 - val_loss: 1.5335 - val_accuracy: 0.8367
# Epoch 40/50
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0351 - accuracy: 0.9913 - val_loss: 1.3512 - val_accuracy: 0.8367
# Epoch 41/50
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0218 - accuracy: 0.9951 - val_loss: 1.5473 - val_accuracy: 0.8435
# Epoch 42/50
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0109 - accuracy: 0.9981 - val_loss: 1.5859 - val_accuracy: 0.8390
# Epoch 43/50
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0133 - accuracy: 0.9961 - val_loss: 1.7320 - val_accuracy: 0.8458
# Epoch 44/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0197 - accuracy: 0.9942 - val_loss: 1.8285 - val_accuracy: 0.8458
# Epoch 45/50
# 33/33 [==============================] - 1s 15ms/step - loss: 0.0255 - accuracy: 0.9932 - val_loss: 1.9313 - val_accuracy: 0.8526
# Epoch 46/50
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0449 - accuracy: 0.9893 - val_loss: 1.7722 - val_accuracy: 0.8526
# Epoch 47/50
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0448 - accuracy: 0.9932 - val_loss: 1.3817 - val_accuracy: 0.8503
# Epoch 48/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0174 - accuracy: 0.9932 - val_loss: 1.4627 - val_accuracy: 0.8594
# Epoch 49/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0163 - accuracy: 0.9971 - val_loss: 1.5717 - val_accuracy: 0.8617
# Epoch 50/50
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0182 - accuracy: 0.9971 - val_loss: 1.4560 - val_accuracy: 0.8549

# %%
training_score = model.evaluate(X_train_std, y_train)
testing_score = model.evaluate(X_test_std, y_test)

print(f"TRAINING SCORE: {training_score}")
print(f"TESTING SCORE: {testing_score}")
# Out:
# 33/33 [==============================] - 0s 8ms/step - loss: 3.6657e-04 - accuracy: 1.0000
# 14/14 [==============================] - 0s 7ms/step - loss: 1.4560 - accuracy: 0.8549
# TRAINING SCORE: [0.000366569118341431, 1.0]
# TESTING SCORE: [1.4559634923934937, 0.8548752665519714]

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.plot(r.history['loss'], label='Loss')
plt.plot(r.history['val_loss'], label='val_Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='accuracy')
plt.legend()

# %%
y_train_pred = model.predict(X_train_std)
y_test_pred = model.predict(X_test_std)

print_score_ann(y_train, y_train_pred.round(), train=True)
print_score_ann(y_test, y_test_pred.round(), train=False)
# Out:
# 33/33 [==============================] - 1s 6ms/step
# 14/14 [==============================] - 0s 7ms/step
# Train Result:
# ================================================
# Accuracy Score: 100.00%
# _______________________________________________
# Classification Report:	Precision Score: 100.00%
# 			Recall Score: 100.00%
# 			F1 score: 100.00%
# _______________________________________________
# Confusion Matrix:
#  [[863   0]
#  [  0 166]]
#
# Test Result:
# ================================================
# Accuracy Score: 85.49%
# _______________________________________________
# Classification Report:	Precision Score: 56.86%
# 			Recall Score: 40.85%
# 			F1 score: 47.54%
# _______________________________________________
# Confusion Matrix:
#  [[348  22]
#  [ 42  29]]

# %% [markdown]
# # Balance the dataset

# %%
X = data.drop('Attrition', axis=1)
y = data.Attrition

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Concatinating X_train and y_train
df = pd.concat([pd.DataFrame(X_train), pd.DataFrame(y_train)], axis=1)
df.head()
# Out:
#       Age  DailyRate  DistanceFromHome  EmployeeNumber  HourlyRate  \
# 714    50       1126                 1             997          66
# 135    36        216                 6             178          84
# 1271   21        337                 7            1780          31
# 477    50       1246                 3             644          99
# 806    52        994                 7            1118          87
#
#       MonthlyIncome  MonthlyRate  TotalWorkingYears  YearsAtCompany  \
# 714           17399         6615                 32               5
# 135            4941         2819                  7               3
# 1271           2679         4567                  1               1
# 477           18200         7999                 32              32
# 806           10445        15322                 18               8
#
#       BusinessTravel_Travel_Frequently  ...  YearsWithCurrManager_9  \
# 714                                  0  ...                       0
# 135                                  0  ...                       0
# 1271                                 0  ...                       0
# 477                                  1  ...                       0
# 806                                  0  ...                       0
#
#       YearsWithCurrManager_10  YearsWithCurrManager_11  \
# 714                         0                        0
# 135                         0                        0
# 1271                        0                        0
# 477                         0                        0
# 806                         0                        0
#
#       YearsWithCurrManager_12  YearsWithCurrManager_13  \
# 714                         0                        0
# 135                         0                        0
# 1271                        0                        0
# 477                         0                        0
# 806                         0                        0
#
#       YearsWithCurrManager_14  YearsWithCurrManager_15  \
# 714                         0                        0
# 135                         0                        0
# 1271                        0                        0
# 477                         0                        0
# 806                         0                        0
#
#       YearsWithCurrManager_16  YearsWithCurrManager_17  Attrition
# 714                         0                        0          0
# 135                         0                        0          0
# 1271                        0                        0          1
# 477                         0                        0          0
# 806                         0                        0          0
#
# [5 rows x 137 columns]

# %%
df.shape
# Out:
# (1029, 137)

# %%
from sklearn.utils import resample

minority_class = df[df.Attrition == 1]
majority_class = df[df.Attrition == 0]

majority_downsample = resample(majority_class, replace=False, 
                               n_samples=minority_class.shape[0], 
                               random_state=42)

df_2 = pd.concat([majority_downsample, minority_class])
df_2.Attrition.value_counts()
# Out:
# 0    176
# 1    176
# Name: Attrition, dtype: int64

# %%
X_train = df_2.drop('Attrition', axis=1)
y_train = df_2.Attrition

scaler = StandardScaler()
X_train_std = scaler.fit_transform(X_train)
X_test_std = scaler.transform(X_test)
X_std = scaler.transform(X)

# %% [markdown]
# # Logistic Regression

# %%
lr_classifier = LogisticRegression(solver='liblinear', penalty='l1')
lr_classifier.fit(X_train_std, y_train)

print_score(lr_classifier, X_train_std, y_train, X_test_std, y_test, train=True)
print_score(lr_classifier, X_train_std, y_train, X_test_std, y_test, train=False)
# Out:
# Train Result:
# ================================================
# Accuracy Score: 91.19%
# _______________________________________________
# Classification Report:	Precision Score: 90.96%
# 			Recall Score: 91.48%
# 			F1 score: 91.22%
# _______________________________________________
# Confusion Matrix:
#  [[160  16]
#  [ 15 161]]
#
# Test Result:
# ================================================
# Accuracy Score: 68.93%
# _______________________________________________
# Classification Report:	Precision Score: 27.38%
# 			Recall Score: 75.41%
# 			F1 score: 40.17%
# _______________________________________________
# Confusion Matrix:
#  [[258 122]
#  [ 15  46]]

# %% [markdown]
# # Random Forest Classifier

# %%
rand_forest = RandomForestClassifier(n_estimators=1500, 
                                     bootstrap=True, 
                                     oob_score=True
                                    )
rand_forest.fit(X_train, y_train)

print_score(rand_forest, X_train, y_train, X_test, y_test, train=True)
print_score(rand_forest, X_train, y_train, X_test, y_test, train=False)
# Out:
# Train Result:
# ================================================
# Accuracy Score: 100.00%
# _______________________________________________
# Classification Report:	Precision Score: 100.00%
# 			Recall Score: 100.00%
# 			F1 score: 100.00%
# _______________________________________________
# Confusion Matrix:
#  [[176   0]
#  [  0 176]]
#
# Test Result:
# ================================================
# Accuracy Score: 74.15%
# _______________________________________________
# Classification Report:	Precision Score: 29.13%
# 			Recall Score: 60.66%
# 			F1 score: 39.36%
# _______________________________________________
# Confusion Matrix:
#  [[290  90]
#  [ 24  37]]

# %%
svc = SVC(kernel='linear')
svc.fit(X_train_std, y_train)

print_score(svc, X_train_std, y_train, X_test_std, y_test, train=True)
print_score(svc, X_train_std, y_train, X_test_std, y_test, train=False)
# Out:
# Train Result:
# ================================================
# Accuracy Score: 94.60%
# _______________________________________________
# Classification Report:	Precision Score: 94.86%
# 			Recall Score: 94.32%
# 			F1 score: 94.59%
# _______________________________________________
# Confusion Matrix:
#  [[167   9]
#  [ 10 166]]
#
# Test Result:
# ================================================
# Accuracy Score: 66.21%
# _______________________________________________
# Classification Report:	Precision Score: 25.28%
# 			Recall Score: 73.77%
# 			F1 score: 37.66%
# _______________________________________________
# Confusion Matrix:
#  [[247 133]
#  [ 16  45]]

# %%
xgb_clf = XGBClassifier()
xgb_clf.fit(X_train, y_train)

print_score(xgb_clf, X_train, y_train, X_test, y_test, train=True)
print_score(xgb_clf, X_train, y_train, X_test, y_test, train=False)
# Out:
# Train Result:
# ================================================
# Accuracy Score: 100.00%
# _______________________________________________
# Classification Report:	Precision Score: 100.00%
# 			Recall Score: 100.00%
# 			F1 score: 100.00%
# _______________________________________________
# Confusion Matrix:
#  [[176   0]
#  [  0 176]]
#
# Test Result:
# ================================================
# Accuracy Score: 73.24%
# _______________________________________________
# Classification Report:	Precision Score: 28.89%
# 			Recall Score: 63.93%
# 			F1 score: 39.80%
# _______________________________________________
# Confusion Matrix:
#  [[284  96]
#  [ 22  39]]

# %%
disp = plot_roc_curve(lr_classifier, X_test_std, y_test)
plot_roc_curve(rand_forest, X_test, y_test, ax=disp.ax_)
plot_roc_curve(svc, X_test_std, y_test, ax=disp.ax_)
plot_roc_curve(xgb_clf, X_test, y_test, ax=disp.ax_)
